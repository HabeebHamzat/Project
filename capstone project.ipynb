# %% [markdown]
# # CAPSTONE PROJECT

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('shark.csv')

# %%
data.columns = data.columns.str.strip()
data.columns

#This is to show us the columns in the data we are working with
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Unnamed: 9', 'Age', 'Injury', 'Fatal (Y/N)',
#        'Time', 'Species', 'Investigator or Source', 'pdf', 'href formula',
#        'href', 'Case Number.1', 'Case Number.2', 'original order',
#        'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
data.head() #the first five information in all the columns
# Out:
#     Case Number                  Date    Year        Type      Country  \
# 0    2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2    2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3    2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4    2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name Unnamed: 9  ...                      Species  \
# ...

# %%
data.tail() #the last five information in all the column
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6457     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6458     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6459     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6460     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6461     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 6457  Western Australia                          Roebuck Bay        Diving
# 6458  Western Australia                                  NaN  Pearl diving
# 6459     North Carolina                       Ocracoke Inlet      Swimming
# 6460                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6461   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Unnamed: 9  ... Species  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6462 entries, 0 to 6461
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6460 non-null   object
#  1   Date                    6461 non-null   object
#  2   Year                    6459 non-null   float64
#  3   Type                    6457 non-null   object
#  4   Country                 6411 non-null   object
#  5   Area                    5999 non-null   object
#  6   Location                5917 non-null   object
#  7   Activity                5910 non-null   object
#  8   Name                    6247 non-null   object
#  9   Unnamed: 9              28 non-null     object
#  10  Age                     3591 non-null   object
#  11  Injury                  6433 non-null   object
#  12  Fatal (Y/N)             5915 non-null   object
#  13  Time                    3070 non-null   object
# ...

# %%
data.isna().sum()
# Out:
# Case Number                  2
# Date                         1
# Year                         3
# Type                         5
# Country                     51
# Area                       463
# Location                   545
# Activity                   552
# Name                       215
# Unnamed: 9                6434
# Age                       2871
# Injury                      29
# Fatal (Y/N)                547
# Time                      3392
# Species                   2924
# Investigator or Source      19
# pdf                       3396
# href formula              3400
# href                      3400
# Case Number.1             3400
# Case Number.2             3400
# original order            3400
# Unnamed: 22               6462
# Unnamed: 23               6460
# dtype: int64

# %%
data = data[data['Year'] >= 1900]
data['Year'] = data['Year'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5719 entries, 0 to 5721
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5718 non-null   object
#  1   Date                    5719 non-null   object
#  2   Year                    5719 non-null   int32
#  3   Type                    5716 non-null   object
#  4   Country                 5695 non-null   object
#  5   Area                    5399 non-null   object
#  6   Location                5339 non-null   object
#  7   Activity                5277 non-null   object
#  8   Name                    5548 non-null   object
#  9   Unnamed: 9              28 non-null     object
#  10  Age                     3498 non-null   object
#  11  Injury                  5700 non-null   object
#  12  Fatal (Y/N)             5249 non-null   object
#  13  Time                    2971 non-null   object
# ...

# %%
data['Case Number'].fillna('Unknown', inplace = True)
data['Date'].fillna('Unknown', inplace = True)
data['Year'].fillna('Unknown', inplace = True)
data['Type'].fillna('Unknown', inplace = True)
data['Country'].fillna('Unknown', inplace = True)
data['Area'].fillna('Unknown', inplace = True)
data['Location'].fillna('Unknown', inplace = True)
data['Activity'].fillna('Unknown', inplace = True)
data['Name'].fillna('Unknown', inplace = True)
data['Unnamed: 9'].fillna('Unknown', inplace = True)
data['Age'].fillna('Unknown', inplace = True)
data['Injury'].fillna('Unknown', inplace = True)
data['Fatal (Y/N)'].fillna('Unknown', inplace = True)
data['Time'].fillna('Unknown', inplace = True)
data['Investigator or Source'].fillna('Unknown', inplace = True)
data['pdf'].fillna('Unknown', inplace = True)
data['href formula'].fillna('Unknown', inplace = True)
data['href'].fillna('Unknown', inplace = True)
data['Case Number.1'].fillna('Unknown', inplace = True)
data['Case Number.2'].fillna('Unknown', inplace = True)
data['original order'].fillna('Unknown', inplace = True)
data['Unnamed: 23'].fillna('Unknown', inplace = True)
data['Species'].fillna('Unknown', inplace = True)

# %%
data.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                      0
# Area                         0
# Location                     0
# Activity                     0
# Name                         0
# Unnamed: 9                   0
# Age                          0
# Injury                       0
# Fatal (Y/N)                  0
# Time                         0
# Species                      0
# Investigator or Source       0
# pdf                          0
# href formula                 0
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5719
# Unnamed: 23                  0
# dtype: int64

# %%
data.drop(columns=['Unnamed: 22'], inplace=True)

# %%
data.drop(columns=['Unnamed: 23'], inplace=True)

# %%
data.isna().sum()
# Out:
# Case Number               0
# Date                      0
# Year                      0
# Type                      0
# Country                   0
# Area                      0
# Location                  0
# Activity                  0
# Name                      0
# Unnamed: 9                0
# Age                       0
# Injury                    0
# Fatal (Y/N)               0
# Time                      0
# Species                   0
# Investigator or Source    0
# pdf                       0
# href formula              0
# href                      0
# Case Number.1             0
# Case Number.2             0
# original order            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5719 entries, 0 to 5721
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5719 non-null   object
#  1   Date                    5719 non-null   object
#  2   Year                    5719 non-null   int32
#  3   Type                    5719 non-null   object
#  4   Country                 5719 non-null   object
#  5   Area                    5719 non-null   object
#  6   Location                5719 non-null   object
#  7   Activity                5719 non-null   object
#  8   Name                    5719 non-null   object
#  9   Unnamed: 9              5719 non-null   object
#  10  Age                     5719 non-null   object
#  11  Injury                  5719 non-null   object
#  12  Fatal (Y/N)             5719 non-null   object
#  13  Time                    5719 non-null   object
# ...

# %%
data.describe(include = 'O')
# Out:
#        Case Number  Date        Type Country     Area Location Activity  Name  \
# count         5719  5719        5719    5719     5719     5719     5719  5719
# unique        5701  4893          13     173      713     3757     1310  4836
# top     2014.08.02  1957  Unprovoked     USA  Florida  Unknown  Surfing  male
# freq             2    11        4163    2162     1045      380     1022   458
#
#        Unnamed: 9      Age  ... Fatal (Y/N)     Time  Species  \
# count        5719     5719  ...        5719     5719     5719
# unique          3      153  ...           7      359     1423
# top       Unknown  Unknown  ...           N  Unknown  Unknown
# freq         5691     2221  ...        4152     2748     2366
#
#        Investigator or Source      pdf href formula     href Case Number.1  \
# count                    5719     5719         5719     5719          5719
# unique                   4381     3055         3052     3052          3055
# ...

# %%
data.head()
# Out:
#     Case Number                  Date  Year        Type      Country  \
# 0    2020.02.05           05-Feb-2020  2020  Unprovoked          USA
# 1  2020.01.30.R  Reported 30-Jan-2020  2020    Provoked      BAHAMAS
# 2    2020.01.17           17-Jan-2020  2020  Unprovoked    AUSTRALIA
# 3    2020.01.16           16-Jan-2020  2020  Unprovoked  NEW ZEALAND
# 4    2020.01.13           13-Jan-2020  2020  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                Unknown  Stand-Up Paddle boarding
# 1           Exumas                Unknown                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name Unnamed: 9  ... Fatal (Y/N)     Time  \
# 0          Unknown    Unknown  ...           N    09h40
# ...

# %%
data['Type'].value_counts()
# Out:
# Unprovoked             4163
# Provoked                558
# Invalid                 481
# Sea Disaster            186
# Watercraft              113
# Boat                    109
# Boating                  92
# Questionable             10
# Unknown                   3
# Unconfirmed               1
# Unverified                1
# Under investigation       1
# Boatomg                   1
# Name: Type, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.countplot(data['Type'])
plt.title('Type of incident')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Type of incident')

# %% [markdown]
# The diagram above shows that the type of incident that leads to most of the attacks are unprovoked, and this implies that irrespective of the activity, being around the beach makes one suceptible to shark attack

# %%
data['Fatal (Y/N)'].value_counts()
# Out:
# N          4152
# Y          1038
# Unknown     470
# UNKNOWN      55
# F             2
# M             1
# 2017          1
# Name: Fatal (Y/N), dtype: int64

# %%
plt.figure(figsize=(12,6))

plt.pie(data['Fatal (Y/N)'].value_counts()[:2], explode= (0.025, 0.05), labels = data['Fatal (Y/N)'].value_counts()[:2].index, colors = ['blue', 'gold'], autopct = '%1.1f%%', startangle = 180)

plt.title('% of fatalitity ratio')
plt.legend()
plt.show()

# %% [markdown]
# The piechart above shows that we have 80% survival rate in shark attacks which is actually a good news

# %%
data['Species'].value_counts()
# Out:
# Unknown                                               2366
# White shark                                            159
# Shark involvement prior to death was not confirmed     105
# Invalid                                                 91
# Shark involvement not confirmed                         87
#                                                       ...
# 1.5 to 2.5 m [5' to 8.25'] copper shark                  1
# 3.7 m to 4.3 m [12' to 14'] white shark                  1
# 3' blacktip shark                                        1
# White shark, 6m [20']                                    1
# Tiger shark, 3.9 m                                       1
# Name: Species, Length: 1423, dtype: int64

# %%
data['Species'].value_counts().index[:20]
# Out:
# Index(['Unknown', 'White shark',
#        'Shark involvement prior to death was not confirmed', 'Invalid',
#        'Shark involvement not confirmed', 'Tiger shark', 'Bull shark',
#        '4' shark', '6' shark', '1.8 m [6'] shark', 'Questionable incident',
#        '1.5 m [5'] shark', '1.2 m [4'] shark',
#        'Shark involvement prior to death unconfirmed', '3' shark', '5' shark',
#        'Questionable', '2 m shark', '4' to 5' shark', 'Wobbegong shark'],
#       dtype='object')

# %%
filter_species = data.set_index('Type')['Species']
filtered_species = filter_species[filter_species != 'Unknown']

plt.figure(figsize = (21,18))
sns.countplot(filtered_species, order= filtered_species.value_counts().index[:20])
plt.xlabel('Species')
plt.tick_params(axis='x', labelrotation=50)
plt.ylabel('Number of attack')
plt.title('Top 20 species with most attack')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Top 20 species with most attack')

# %% [markdown]
# The countplot above shows the top 20 species with most attack and it can be confirmed that white shark is the most dangerous specie

# %%
data['Activity'].value_counts()[:20]
# Out:
# Surfing            1022
# Swimming            813
# Unknown             445
# Fishing             406
# Spearfishing        345
# Wading              151
# Diving              111
# Snorkeling           99
# Standing             96
# Scuba diving         79
# Bathing              76
# Body boarding        62
# Body surfing         50
# Kayaking             37
# Boogie boarding      36
# Treading water       32
# Free diving          29
# Pearl diving         22
# Surf skiing          20
# Windsurfing          19
# Name: Activity, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.style.use('seaborn-dark')
top_20 = data['Activity'].value_counts()[:20]
top_20.plot(kind='bar')
plt.title('Top 20 activities that caused the shark attack')
# Out:
# Text(0.5, 1.0, 'Top 20 activities that caused the shark attack')

# %% [markdown]
# This diagram above shows that surfing is the activity that has led to most attacks, followed by swimming, so whosever is going to participate in theese activities while at the beach should be very careful.

# %%
data['Country'].value_counts()[:10]
# Out:
# USA                 2162
# AUSTRALIA           1216
# SOUTH AFRICA         555
# PAPUA NEW GUINEA     131
# BRAZIL               109
# BAHAMAS              106
# NEW ZEALAND          104
# MEXICO                84
# ITALY                 61
# PHILIPPINES           58
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.style.use('seaborn-dark')
top_20 = data['Country'].value_counts()[:20]
top_20.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The bar chart shows the top 20 countries with most attacks and it shows that USA has the most attack with over 2000 attacks from the country alone followed by Australia with over 1000 attacks.

# %%
data['Year'].value_counts()
# Out:
# 2015    143
# 2017    138
# 2016    130
# 2011    128
# 2014    127
#        ...
# 1903     10
# 2020     10
# 1901      9
# 1918      5
# 3019      1
# Name: Year, Length: 122, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.style.use('seaborn-dark')
top_20 = data['Year'].value_counts()[:20]
top_20.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The bar chart above shows the top 20 years with most attack and we can see that most of the attacks happened in the twenty first century with 2015 being the one with the most attack

# %%
data['Area'].value_counts()
# Out:
# Florida                                       1045
# New South Wales                                435
# Unknown                                        320
# Queensland                                     294
# Hawaii                                         289
#                                               ...
# On the Kowloon penisula, south of Sai Kung       1
# Walkers Cay                                      1
# Costa Blanca                                     1
# Kagoshima Prefecture                             1
# Western Viscayas                                 1
# Name: Area, Length: 713, dtype: int64

# %%
data['Area'].value_counts()[:20]
# Out:
# Florida                  1045
# New South Wales           435
# Unknown                   320
# Queensland                294
# Hawaii                    289
# California                288
# KwaZulu-Natal             200
# Western Cape Province     187
# Western Australia         184
# Eastern Cape Province     158
# South Carolina            145
# North Carolina            101
# South Australia            93
# Victoria                   75
# Pernambuco                 74
# Texas                      70
# Torres Strait              67
# North Island               51
# New Jersey                 45
# Tasmania                   34
# Name: Area, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.style.use('seaborn-dark')
top_20 = data['Area'].value_counts()[:20]
top_20.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The bar chart above shows the top20 areas with most attack with florida with over 1000 recorded attacks followed by new south wales with over 400 attacks, so whoever is visiting the beach around these locations should be very careful.

# %%
data['Unnamed: 9'].value_counts()
# Out:
# Unknown    5691
# M            24
# F             4
# Name: Unnamed: 9, dtype: int64

# %%
plt.figure(figsize=(12,6))

plt.pie(data['Unnamed: 9'].value_counts()[1:], explode= (0.025, 0.05), labels = data['Unnamed: 9'].value_counts()[1:].index, colors = ['blue', 'gold'], autopct = '%1.1f%%', startangle = 180)

plt.title('% of attack recorded by gender')
plt.legend()
plt.show()

# %% [markdown]
# The pie chart above shows that out of the recorded attack Males are the ones mostly hit than the females

# %%
sns.pointplot(data=titanic, x='sex', y='survived', hue='class', palette='dark')

# %%
sns.scatterplot( x=data['Area'].value_counts()[1:20], y=data['Species'].value_counts().index[1:20])
# Out:
# <AxesSubplot:xlabel='Area'>

# %% [markdown]
# The scatteredplot is to show the relationship between the top species of Attacks and the areas, and it showed that white shark can be found in almost 450 areas and that is a whole lot.

# %%
data['Time'].value_counts()
# Out:
# Unknown            2748
# Afternoon           177
# 11h00               130
# Morning             118
# 15h00               109
#                    ...
# 07h08                 1
# 17h00 or 17h40        1
# >08h00                1
# 12h02                 1
# "Early evening"       1
# Name: Time, Length: 359, dtype: int64

# %%
filter_Time = data.set_index('Type')['Time']
filtered_Time = filter_Time[filter_Time != 'Unknown']

plt.figure(figsize = (21,18))
sns.countplot(filtered_Time, order= filtered_Time.value_counts().index[:20])
plt.xlabel('Time')
plt.tick_params(axis='x', labelrotation=50)
plt.ylabel('Number of attack')
plt.title('The most dangerous time to be at the beach')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'The most dangerous time to be at the beach')

# %% [markdown]
# The countplot above shows that the period most of these attacks happen is in the afternoon, making it the most dangerous time to be at the beach

# %%
data['Location'].value_counts()
# Out:
# Unknown                                                     380
# New Smyrna Beach, Volusia County                            181
# Daytona Beach, Volusia County                                34
# Cocoa Beach, Brevard County                                  26
# Ponce Inlet, Volusia County                                  21
#                                                            ...
# Brenecke Beach, Po'ipu, Kaua'i                                1
# Deerfield Beach (near Boca Raton), Broward County             1
# Lifou                                                         1
# Paramatta River (near Sydney)                                 1
# Inter-Island Dry Dock at Kakaako Street, Honolulu, O'ahu      1
# Name: Location, Length: 3757, dtype: int64

# %%
filter_Location = data.set_index('Type')['Location']
filtered_Location = filter_Location[filter_Location != 'Unknown']

plt.figure(figsize = (21,18))
sns.countplot(filtered_Location, order= filtered_Location.value_counts().index[:20])
plt.xlabel('Time')
plt.tick_params(axis='x', labelrotation=50)
plt.ylabel('Number of attack')
plt.title('The most dangerous beach')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'The most dangerous beach')

# %% [markdown]
# The count plot above shows the top 20 beaches with most attacks and New Smyrna Beach, Volusia County has the most with over 180 attack making it by far the most dangerous beach to be at.

# %%
sns.scatterplot( x=data['Location'].value_counts()[1:20], y=data['Time'].value_counts().index[1:20])
# Out:
# <AxesSubplot:xlabel='Location'>

# %% [markdown]
# The count plot is showing the relationships between the Time and the location of these attacks, and it shows that apart from afternoon which is far dangerous in any location, the rate of danger during the other periods is relatively the same irrespective of the location
